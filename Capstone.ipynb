# %% [markdown]
# <a href="https://colab.research.google.com/github/codingcris/my-first-repository/blob/master/Capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **We import our data first**

# %%
import pandas as pd

df = pd.read_csv('/content/Capstone/AAPL.csv')

# %%
df
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099450
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094261
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087343
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089504
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092099
# ...           ...         ...         ...         ...         ...         ...
# 10755  2023-08-11  177.320007  178.619995  176.550003  177.789993  177.789993
# 10756  2023-08-14  177.970001  179.690002  177.309998  179.460007  179.460007
# 10757  2023-08-15  178.880005  179.479996  177.050003  177.449997  177.449997
# 10758  2023-08-16  177.130005  178.539993  176.500000  176.570007  176.570007
# 10759  2023-08-17  177.139999  177.509995  173.479996  174.000000  174.000000
#
#           Volume
# 0      469033600
# 1      175884800
# 2      105728000
# 3       86441600
# 4       73449600
# ...          ...
# 10755   51988100
# 10756   43675600
# 10757   43622600
# 10758   46964900
# 10759   66062900
#
# [10760 rows x 7 columns]

# %% [markdown]
# **We only need the closing price and the date for our model so we drop the other columns**

# %%
df = df[['Date', 'Close']]

# %%
df
# Out:
#              Date       Close
# 0      1980-12-12    0.128348
# 1      1980-12-15    0.121652
# 2      1980-12-16    0.112723
# 3      1980-12-17    0.115513
# 4      1980-12-18    0.118862
# ...           ...         ...
# 10755  2023-08-11  177.789993
# 10756  2023-08-14  179.460007
# 10757  2023-08-15  177.449997
# 10758  2023-08-16  176.570007
# 10759  2023-08-17  174.000000
#
# [10760 rows x 2 columns]

# %% [markdown]
# **We transform our Date column values from strings to datetime objects.**

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
# Out:
# <ipython-input-121-82fc7f804c29>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)

# %%
df
# Out:
#             Date       Close
# 0     1980-12-12    0.128348
# 1     1980-12-15    0.121652
# 2     1980-12-16    0.112723
# 3     1980-12-17    0.115513
# 4     1980-12-18    0.118862
# ...          ...         ...
# 10755 2023-08-11  177.789993
# 10756 2023-08-14  179.460007
# 10757 2023-08-15  177.449997
# 10758 2023-08-16  176.570007
# 10759 2023-08-17  174.000000
#
# [10760 rows x 2 columns]

# %% [markdown]
# **Date column becomes the dataframe index.**

# %%
df.index = df.pop('Date')

# %%
df
# Out:
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2023-08-11  177.789993
# 2023-08-14  179.460007
# 2023-08-15  177.449997
# 2023-08-16  176.570007
# 2023-08-17  174.000000
#
# [10760 rows x 1 columns]

# %% [markdown]
# **We can now see the historical prices of our stocks.**

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %% [markdown]
# **Our tensorflow model expects the data  in the format output to us by the following function: *df_to_windowed_df***

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=5):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# %% [markdown]
# The returned dataframe contains 7 columns. For any given date it holds the date (target date), an additional 5 columns labeled Target-N where N represents the number of days back from our target date from 1 to 5 days, and finally the target column containing the closing value of our stock on the target date. You can gather that our model looks 5 days back in order to make a prediction about the closing price on a predicted date.

# %%
windowed_df = df_to_windowed_df(df,
                                '1980-12-19',
                                '2023-08-15',
                                 n=5)

# %%
windowed_df
# Out:
#       Target Date    Target-5    Target-4    Target-3    Target-2    Target-1  \
# 0      1980-12-19    0.128348    0.121652    0.112723    0.115513    0.118862
# 1      1980-12-22    0.121652    0.112723    0.115513    0.118862    0.126116
# 2      1980-12-23    0.112723    0.115513    0.118862    0.126116    0.132254
# 3      1980-12-24    0.115513    0.118862    0.126116    0.132254    0.137835
# 4      1980-12-26    0.118862    0.126116    0.132254    0.137835    0.145089
# ...           ...         ...         ...         ...         ...         ...
# 10748  2023-08-09  192.580002  191.169998  181.990005  178.850006  179.800003
# 10749  2023-08-10  191.169998  181.990005  178.850006  179.800003  178.190002
# 10750  2023-08-11  181.990005  178.850006  179.800003  178.190002  177.970001
# 10751  2023-08-14  178.850006  179.800003  178.190002  177.970001  177.789993
# 10752  2023-08-15  179.800003  178.190002  177.970001  177.789993  179.460007
#
#            Target
# 0        0.126116
# 1        0.132254
# 2        0.137835
# 3        0.145089
# 4        0.158482
# ...           ...
# 10748  178.190002
# 10749  177.970001
# 10750  177.789993
# 10751  179.460007
# 10752  177.449997
#
# [10753 rows x 7 columns]

# %% [markdown]
# **Our tensorflow model wants that data in a specific format, we must also divide our data into train and test sets.**

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((10753,), (10753, 5, 1), (10753,))

# %% [markdown]
# **We use 80 percent of our historical data for training, 10 percent for validation,  and the remaining 10 percent for testing.**

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %% [markdown]
# **Our data is ready to be input for our model. We import tenserflow and create a LSTM model. We compile our model and fit it to our data.**
# our LSTM is given 64 neurons split onto 2 dense layers and it outputs a single value, the predicted closing price after the 5 days considered.
# We compile our model using the mean squared error (mse) as our loss function and setting a small learning rate. We use the mean absolute error as an additional metric. The model runs for 100 epochs

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((5, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 269/269 [==============================] - 6s 10ms/step - loss: 5.9004 - mean_absolute_error: 0.5802 - val_loss: 134.5933 - val_mean_absolute_error: 8.2723
# Epoch 2/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0356 - mean_absolute_error: 0.0744 - val_loss: 117.6560 - val_mean_absolute_error: 7.5173
# Epoch 3/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0274 - mean_absolute_error: 0.0675 - val_loss: 107.1665 - val_mean_absolute_error: 7.0528
# Epoch 4/100
# 269/269 [==============================] - 3s 11ms/step - loss: 0.0234 - mean_absolute_error: 0.0640 - val_loss: 100.0777 - val_mean_absolute_error: 6.8059
# Epoch 5/100
# 269/269 [==============================] - 3s 13ms/step - loss: 0.0264 - mean_absolute_error: 0.0670 - val_loss: 98.7986 - val_mean_absolute_error: 6.7465
# Epoch 6/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0207 - mean_absolute_error: 0.0606 - val_loss: 91.1442 - val_mean_absolute_error: 6.3398
# Epoch 7/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0215 - mean_absolute_error: 0.0587 - val_loss: 88.7548 - val_mean_absolute_error: 6.2871
# Epoch 8/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0277 - mean_absolute_error: 0.0709 - val_loss: 81.2188 - val_mean_absolute_error: 5.9292
# Epoch 9/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0321 - mean_absolute_error: 0.0737 - val_loss: 75.0358 - val_mean_absolute_error: 5.6661
# Epoch 10/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0222 - mean_absolute_error: 0.0613 - val_loss: 74.8859 - val_mean_absolute_error: 5.6802
# Epoch 11/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0187 - mean_absolute_error: 0.0565 - val_loss: 71.0850 - val_mean_absolute_error: 5.4529
# Epoch 12/100
# 269/269 [==============================] - 3s 9ms/step - loss: 0.0268 - mean_absolute_error: 0.0697 - val_loss: 71.1652 - val_mean_absolute_error: 5.4826
# Epoch 13/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0222 - mean_absolute_error: 0.0610 - val_loss: 72.7959 - val_mean_absolute_error: 5.6501
# Epoch 14/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0191 - mean_absolute_error: 0.0568 - val_loss: 71.6941 - val_mean_absolute_error: 5.5030
# Epoch 15/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0229 - mean_absolute_error: 0.0639 - val_loss: 73.3991 - val_mean_absolute_error: 5.6982
# Epoch 16/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0199 - mean_absolute_error: 0.0579 - val_loss: 69.1918 - val_mean_absolute_error: 5.4365
# Epoch 17/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0226 - mean_absolute_error: 0.0628 - val_loss: 69.2962 - val_mean_absolute_error: 5.4293
# Epoch 18/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0223 - mean_absolute_error: 0.0622 - val_loss: 68.6571 - val_mean_absolute_error: 5.5188
# Epoch 19/100
# 269/269 [==============================] - 3s 9ms/step - loss: 0.0260 - mean_absolute_error: 0.0667 - val_loss: 64.3416 - val_mean_absolute_error: 5.1984
# Epoch 20/100
# 269/269 [==============================] - 2s 9ms/step - loss: 0.0214 - mean_absolute_error: 0.0619 - val_loss: 64.4328 - val_mean_absolute_error: 5.2152
# Epoch 21/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0207 - mean_absolute_error: 0.0606 - val_loss: 67.3640 - val_mean_absolute_error: 5.4654
# Epoch 22/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0206 - mean_absolute_error: 0.0609 - val_loss: 68.9896 - val_mean_absolute_error: 5.5546
# Epoch 23/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0224 - mean_absolute_error: 0.0628 - val_loss: 64.2551 - val_mean_absolute_error: 5.2642
# Epoch 24/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0229 - mean_absolute_error: 0.0635 - val_loss: 53.1353 - val_mean_absolute_error: 4.9656
# Epoch 25/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0289 - mean_absolute_error: 0.0684 - val_loss: 52.1249 - val_mean_absolute_error: 4.7632
# Epoch 26/100
# 269/269 [==============================] - 2s 9ms/step - loss: 0.0208 - mean_absolute_error: 0.0602 - val_loss: 59.9657 - val_mean_absolute_error: 5.0537
# Epoch 27/100
# 269/269 [==============================] - 3s 9ms/step - loss: 0.0216 - mean_absolute_error: 0.0614 - val_loss: 61.0285 - val_mean_absolute_error: 5.0994
# Epoch 28/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0208 - mean_absolute_error: 0.0597 - val_loss: 59.1474 - val_mean_absolute_error: 4.9921
# Epoch 29/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0198 - mean_absolute_error: 0.0595 - val_loss: 52.2166 - val_mean_absolute_error: 4.7910
# Epoch 30/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0238 - mean_absolute_error: 0.0684 - val_loss: 54.1431 - val_mean_absolute_error: 4.7498
# Epoch 31/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0224 - mean_absolute_error: 0.0635 - val_loss: 59.1600 - val_mean_absolute_error: 5.1920
# Epoch 32/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0218 - mean_absolute_error: 0.0616 - val_loss: 49.4251 - val_mean_absolute_error: 4.4775
# Epoch 33/100
# 269/269 [==============================] - 3s 9ms/step - loss: 0.0221 - mean_absolute_error: 0.0606 - val_loss: 48.4554 - val_mean_absolute_error: 4.4387
# Epoch 34/100
# 269/269 [==============================] - 2s 9ms/step - loss: 0.0201 - mean_absolute_error: 0.0590 - val_loss: 53.1475 - val_mean_absolute_error: 4.7707
# Epoch 35/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0249 - mean_absolute_error: 0.0666 - val_loss: 50.9455 - val_mean_absolute_error: 4.6938
# Epoch 36/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0216 - mean_absolute_error: 0.0609 - val_loss: 46.7111 - val_mean_absolute_error: 4.3903
# Epoch 37/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0195 - mean_absolute_error: 0.0577 - val_loss: 59.6737 - val_mean_absolute_error: 5.3349
# Epoch 38/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0292 - mean_absolute_error: 0.0732 - val_loss: 46.1919 - val_mean_absolute_error: 4.3332
# Epoch 39/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0192 - mean_absolute_error: 0.0570 - val_loss: 48.9165 - val_mean_absolute_error: 4.5048
# Epoch 40/100
# 269/269 [==============================] - 2s 9ms/step - loss: 0.0230 - mean_absolute_error: 0.0634 - val_loss: 50.0238 - val_mean_absolute_error: 4.6520
# Epoch 41/100
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0220 - mean_absolute_error: 0.0632 - val_loss: 44.4256 - val_mean_absolute_error: 4.2984
# Epoch 42/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0189 - mean_absolute_error: 0.0568 - val_loss: 44.3959 - val_mean_absolute_error: 4.2308
# Epoch 43/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0189 - mean_absolute_error: 0.0579 - val_loss: 56.5114 - val_mean_absolute_error: 5.1016
# Epoch 44/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0219 - mean_absolute_error: 0.0607 - val_loss: 43.2865 - val_mean_absolute_error: 4.1783
# Epoch 45/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0218 - mean_absolute_error: 0.0615 - val_loss: 42.9291 - val_mean_absolute_error: 4.1801
# Epoch 46/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0238 - mean_absolute_error: 0.0621 - val_loss: 44.4200 - val_mean_absolute_error: 4.2931
# Epoch 47/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0211 - mean_absolute_error: 0.0613 - val_loss: 44.4702 - val_mean_absolute_error: 4.3272
# Epoch 48/100
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0255 - mean_absolute_error: 0.0663 - val_loss: 44.9277 - val_mean_absolute_error: 4.3332
# Epoch 49/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0206 - mean_absolute_error: 0.0592 - val_loss: 47.9448 - val_mean_absolute_error: 4.5819
# Epoch 50/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0190 - mean_absolute_error: 0.0564 - val_loss: 49.5534 - val_mean_absolute_error: 4.6231
# Epoch 51/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0206 - mean_absolute_error: 0.0594 - val_loss: 53.0612 - val_mean_absolute_error: 4.8752
# Epoch 52/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0271 - mean_absolute_error: 0.0662 - val_loss: 47.5181 - val_mean_absolute_error: 4.4938
# Epoch 53/100
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0181 - mean_absolute_error: 0.0546 - val_loss: 49.2586 - val_mean_absolute_error: 4.5866
# Epoch 54/100
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0188 - mean_absolute_error: 0.0559 - val_loss: 44.0070 - val_mean_absolute_error: 4.3192
# Epoch 55/100
# 269/269 [==============================] - 2s 9ms/step - loss: 0.0186 - mean_absolute_error: 0.0574 - val_loss: 43.0438 - val_mean_absolute_error: 4.2421
# Epoch 56/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0235 - mean_absolute_error: 0.0638 - val_loss: 42.2275 - val_mean_absolute_error: 4.1820
# Epoch 57/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0214 - mean_absolute_error: 0.0611 - val_loss: 49.6968 - val_mean_absolute_error: 4.6960
# Epoch 58/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0206 - mean_absolute_error: 0.0585 - val_loss: 50.4769 - val_mean_absolute_error: 4.6480
# Epoch 59/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0191 - mean_absolute_error: 0.0572 - val_loss: 39.0508 - val_mean_absolute_error: 3.9232
# Epoch 60/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0217 - mean_absolute_error: 0.0601 - val_loss: 40.1863 - val_mean_absolute_error: 4.0600
# Epoch 61/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0216 - mean_absolute_error: 0.0601 - val_loss: 49.8254 - val_mean_absolute_error: 4.7700
# Epoch 62/100
# 269/269 [==============================] - 2s 9ms/step - loss: 0.0218 - mean_absolute_error: 0.0602 - val_loss: 43.6741 - val_mean_absolute_error: 4.2454
# Epoch 63/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0192 - mean_absolute_error: 0.0587 - val_loss: 42.5489 - val_mean_absolute_error: 4.1214
# Epoch 64/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0204 - mean_absolute_error: 0.0604 - val_loss: 38.7419 - val_mean_absolute_error: 3.9118
# Epoch 65/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0185 - mean_absolute_error: 0.0558 - val_loss: 43.9608 - val_mean_absolute_error: 4.4349
# Epoch 66/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0234 - mean_absolute_error: 0.0648 - val_loss: 37.7166 - val_mean_absolute_error: 3.9240
# Epoch 67/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0228 - mean_absolute_error: 0.0629 - val_loss: 42.5756 - val_mean_absolute_error: 4.1843
# Epoch 68/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0216 - mean_absolute_error: 0.0599 - val_loss: 39.8254 - val_mean_absolute_error: 3.9719
# Epoch 69/100
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0214 - mean_absolute_error: 0.0600 - val_loss: 41.6085 - val_mean_absolute_error: 4.1256
# Epoch 70/100
# 269/269 [==============================] - 2s 9ms/step - loss: 0.0195 - mean_absolute_error: 0.0580 - val_loss: 48.7709 - val_mean_absolute_error: 4.5655
# Epoch 71/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0191 - mean_absolute_error: 0.0591 - val_loss: 46.3082 - val_mean_absolute_error: 4.6013
# Epoch 72/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0255 - mean_absolute_error: 0.0662 - val_loss: 57.7467 - val_mean_absolute_error: 5.2217
# Epoch 73/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0193 - mean_absolute_error: 0.0571 - val_loss: 47.1592 - val_mean_absolute_error: 4.4821
# Epoch 74/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0188 - mean_absolute_error: 0.0576 - val_loss: 47.4163 - val_mean_absolute_error: 4.5229
# Epoch 75/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0206 - mean_absolute_error: 0.0610 - val_loss: 39.5612 - val_mean_absolute_error: 3.9711
# Epoch 76/100
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0191 - mean_absolute_error: 0.0573 - val_loss: 49.4395 - val_mean_absolute_error: 4.5915
# Epoch 77/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0196 - mean_absolute_error: 0.0571 - val_loss: 41.5349 - val_mean_absolute_error: 4.1032
# Epoch 78/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0192 - mean_absolute_error: 0.0571 - val_loss: 38.1528 - val_mean_absolute_error: 3.9061
# Epoch 79/100
# 269/269 [==============================] - 2s 9ms/step - loss: 0.0184 - mean_absolute_error: 0.0560 - val_loss: 45.5265 - val_mean_absolute_error: 4.3327
# Epoch 80/100
# 269/269 [==============================] - 4s 13ms/step - loss: 0.0198 - mean_absolute_error: 0.0577 - val_loss: 42.9023 - val_mean_absolute_error: 4.1558
# Epoch 81/100
# 269/269 [==============================] - 4s 15ms/step - loss: 0.0202 - mean_absolute_error: 0.0590 - val_loss: 45.4749 - val_mean_absolute_error: 4.4747
# Epoch 82/100
# 269/269 [==============================] - 4s 16ms/step - loss: 0.0188 - mean_absolute_error: 0.0572 - val_loss: 42.9562 - val_mean_absolute_error: 4.3415
# Epoch 83/100
# 269/269 [==============================] - 4s 14ms/step - loss: 0.0226 - mean_absolute_error: 0.0622 - val_loss: 40.3500 - val_mean_absolute_error: 4.0660
# Epoch 84/100
# 269/269 [==============================] - 4s 14ms/step - loss: 0.0227 - mean_absolute_error: 0.0637 - val_loss: 38.6883 - val_mean_absolute_error: 3.9573
# Epoch 85/100
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0182 - mean_absolute_error: 0.0555 - val_loss: 40.0426 - val_mean_absolute_error: 4.0979
# Epoch 86/100
# 269/269 [==============================] - 2s 9ms/step - loss: 0.0188 - mean_absolute_error: 0.0574 - val_loss: 36.5321 - val_mean_absolute_error: 3.7673
# Epoch 87/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0199 - mean_absolute_error: 0.0596 - val_loss: 44.9515 - val_mean_absolute_error: 4.2807
# Epoch 88/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0221 - mean_absolute_error: 0.0608 - val_loss: 39.5325 - val_mean_absolute_error: 3.9827
# Epoch 89/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0191 - mean_absolute_error: 0.0581 - val_loss: 41.3859 - val_mean_absolute_error: 4.2577
# Epoch 90/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0207 - mean_absolute_error: 0.0588 - val_loss: 37.2409 - val_mean_absolute_error: 3.8241
# Epoch 91/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0202 - mean_absolute_error: 0.0592 - val_loss: 43.8455 - val_mean_absolute_error: 4.3562
# Epoch 92/100
# 269/269 [==============================] - 2s 9ms/step - loss: 0.0236 - mean_absolute_error: 0.0616 - val_loss: 41.8722 - val_mean_absolute_error: 4.1079
# Epoch 93/100
# 269/269 [==============================] - 2s 9ms/step - loss: 0.0185 - mean_absolute_error: 0.0548 - val_loss: 37.1425 - val_mean_absolute_error: 3.8352
# Epoch 94/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0179 - mean_absolute_error: 0.0542 - val_loss: 45.5616 - val_mean_absolute_error: 4.3538
# Epoch 95/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0205 - mean_absolute_error: 0.0595 - val_loss: 35.2375 - val_mean_absolute_error: 3.6984
# Epoch 96/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0192 - mean_absolute_error: 0.0573 - val_loss: 38.2866 - val_mean_absolute_error: 4.0124
# Epoch 97/100
# 269/269 [==============================] - 2s 7ms/step - loss: 0.0229 - mean_absolute_error: 0.0629 - val_loss: 47.0075 - val_mean_absolute_error: 4.4591
# Epoch 98/100
# 269/269 [==============================] - 2s 8ms/step - loss: 0.0214 - mean_absolute_error: 0.0597 - val_loss: 60.7918 - val_mean_absolute_error: 5.2719
# Epoch 99/100
# 269/269 [==============================] - 2s 9ms/step - loss: 0.0198 - mean_absolute_error: 0.0593 - val_loss: 37.3544 - val_mean_absolute_error: 3.8539
# Epoch 100/100
# 269/269 [==============================] - 3s 9ms/step - loss: 0.0195 - mean_absolute_error: 0.0574 - val_loss: 39.1483 - val_mean_absolute_error: 4.0479

# %% [markdown]
# **We can see our training predictions with our training observations:**

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 269/269 [==============================] - 1s 3ms/step

# %% [markdown]
# **Our validation predictions vs our validation observations:**

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 34/34 [==============================] - 0s 3ms/step

# %% [markdown]
# **Our testing predictions vs our testing observations:**

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 34/34 [==============================] - 0s 2ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %% [markdown]
# This model demonstrates how LSTM's aren't the best at extrapolating. By using the entire historical price of the stock for our model, we are hindering its predictive power in the near future. Lets see how changing the dataset to the past year changes our results:

# %%
windowed_df = df_to_windowed_df(df,
                                '2022-08-15',
                                '2023-08-15',
                                 n=5)
dates, X, y = windowed_df_to_date_X_y(windowed_df)

q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 0s 23ms/step - loss: 11549.1406 - mean_absolute_error: 106.1975 - val_loss: 12695.2275 - val_mean_absolute_error: 112.5814
# Epoch 2/100
# 7/7 [==============================] - 0s 13ms/step - loss: 3581.4758 - mean_absolute_error: 56.5935 - val_loss: 2567.5627 - val_mean_absolute_error: 50.4792
# Epoch 3/100
# 7/7 [==============================] - 0s 16ms/step - loss: 485.3578 - mean_absolute_error: 18.7063 - val_loss: 28.4865 - val_mean_absolute_error: 4.4302
# Epoch 4/100
# 7/7 [==============================] - 0s 18ms/step - loss: 914.8238 - mean_absolute_error: 27.2291 - val_loss: 350.6034 - val_mean_absolute_error: 18.2022
# Epoch 5/100
# 7/7 [==============================] - 0s 13ms/step - loss: 222.3290 - mean_absolute_error: 12.1806 - val_loss: 1567.4351 - val_mean_absolute_error: 39.3466
# Epoch 6/100
# 7/7 [==============================] - 0s 15ms/step - loss: 243.9501 - mean_absolute_error: 12.4932 - val_loss: 1928.0132 - val_mean_absolute_error: 43.6891
# Epoch 7/100
# 7/7 [==============================] - 0s 15ms/step - loss: 237.5828 - mean_absolute_error: 12.2874 - val_loss: 1391.6086 - val_mean_absolute_error: 37.0450
# Epoch 8/100
# 7/7 [==============================] - 0s 13ms/step - loss: 171.8937 - mean_absolute_error: 10.6591 - val_loss: 942.7933 - val_mean_absolute_error: 30.3896
# Epoch 9/100
# 7/7 [==============================] - 0s 12ms/step - loss: 160.1450 - mean_absolute_error: 10.4867 - val_loss: 994.2349 - val_mean_absolute_error: 31.2478
# Epoch 10/100
# 7/7 [==============================] - 0s 17ms/step - loss: 108.7403 - mean_absolute_error: 8.3524 - val_loss: 838.9587 - val_mean_absolute_error: 28.6444
# Epoch 11/100
# 7/7 [==============================] - 0s 12ms/step - loss: 102.7765 - mean_absolute_error: 8.1858 - val_loss: 741.1780 - val_mean_absolute_error: 26.8768
# Epoch 12/100
# 7/7 [==============================] - 0s 11ms/step - loss: 96.0772 - mean_absolute_error: 7.8885 - val_loss: 777.8017 - val_mean_absolute_error: 27.5811
# Epoch 13/100
# 7/7 [==============================] - 0s 12ms/step - loss: 89.9681 - mean_absolute_error: 7.5213 - val_loss: 732.6315 - val_mean_absolute_error: 26.7457
# Epoch 14/100
# 7/7 [==============================] - 0s 11ms/step - loss: 82.6349 - mean_absolute_error: 7.1921 - val_loss: 674.0211 - val_mean_absolute_error: 25.6207
# Epoch 15/100
# 7/7 [==============================] - 0s 12ms/step - loss: 71.8727 - mean_absolute_error: 6.7268 - val_loss: 700.5558 - val_mean_absolute_error: 26.1411
# Epoch 16/100
# 7/7 [==============================] - 0s 13ms/step - loss: 65.0258 - mean_absolute_error: 6.3404 - val_loss: 557.1775 - val_mean_absolute_error: 23.2449
# Epoch 17/100
# 7/7 [==============================] - 0s 15ms/step - loss: 61.6360 - mean_absolute_error: 6.2581 - val_loss: 590.8422 - val_mean_absolute_error: 23.9932
# Epoch 18/100
# 7/7 [==============================] - 0s 11ms/step - loss: 63.7322 - mean_absolute_error: 6.3507 - val_loss: 507.2887 - val_mean_absolute_error: 22.1560
# Epoch 19/100
# 7/7 [==============================] - 0s 13ms/step - loss: 53.2784 - mean_absolute_error: 5.8604 - val_loss: 479.8566 - val_mean_absolute_error: 21.5180
# Epoch 20/100
# 7/7 [==============================] - 0s 11ms/step - loss: 45.2965 - mean_absolute_error: 5.2870 - val_loss: 465.7975 - val_mean_absolute_error: 21.2205
# Epoch 21/100
# 7/7 [==============================] - 0s 15ms/step - loss: 41.6041 - mean_absolute_error: 5.0169 - val_loss: 422.8782 - val_mean_absolute_error: 20.1868
# Epoch 22/100
# 7/7 [==============================] - 0s 13ms/step - loss: 38.9451 - mean_absolute_error: 4.9476 - val_loss: 424.6728 - val_mean_absolute_error: 20.2294
# Epoch 23/100
# 7/7 [==============================] - 0s 12ms/step - loss: 36.1611 - mean_absolute_error: 4.8533 - val_loss: 368.5760 - val_mean_absolute_error: 18.7824
# Epoch 24/100
# 7/7 [==============================] - 0s 13ms/step - loss: 31.7110 - mean_absolute_error: 4.4528 - val_loss: 350.1119 - val_mean_absolute_error: 18.2819
# Epoch 25/100
# 7/7 [==============================] - 0s 15ms/step - loss: 27.5328 - mean_absolute_error: 4.0725 - val_loss: 345.6653 - val_mean_absolute_error: 18.1611
# Epoch 26/100
# 7/7 [==============================] - 0s 15ms/step - loss: 28.2420 - mean_absolute_error: 4.1571 - val_loss: 326.6714 - val_mean_absolute_error: 17.6210
# Epoch 27/100
# 7/7 [==============================] - 0s 15ms/step - loss: 28.7968 - mean_absolute_error: 4.3773 - val_loss: 305.5546 - val_mean_absolute_error: 17.0049
# Epoch 28/100
# 7/7 [==============================] - 0s 12ms/step - loss: 26.1375 - mean_absolute_error: 4.2237 - val_loss: 292.0621 - val_mean_absolute_error: 16.5954
# Epoch 29/100
# 7/7 [==============================] - 0s 16ms/step - loss: 22.8702 - mean_absolute_error: 3.9262 - val_loss: 275.1333 - val_mean_absolute_error: 16.0692
# Epoch 30/100
# 7/7 [==============================] - 0s 17ms/step - loss: 21.1228 - mean_absolute_error: 3.6610 - val_loss: 260.2947 - val_mean_absolute_error: 15.6009
# Epoch 31/100
# 7/7 [==============================] - 0s 15ms/step - loss: 18.9470 - mean_absolute_error: 3.4423 - val_loss: 261.5025 - val_mean_absolute_error: 15.6530
# Epoch 32/100
# 7/7 [==============================] - 0s 11ms/step - loss: 17.4957 - mean_absolute_error: 3.3814 - val_loss: 248.7670 - val_mean_absolute_error: 15.2350
# Epoch 33/100
# 7/7 [==============================] - 0s 13ms/step - loss: 17.0763 - mean_absolute_error: 3.3254 - val_loss: 235.2296 - val_mean_absolute_error: 14.7748
# Epoch 34/100
# 7/7 [==============================] - 0s 16ms/step - loss: 18.0238 - mean_absolute_error: 3.4134 - val_loss: 231.0900 - val_mean_absolute_error: 14.6341
# Epoch 35/100
# 7/7 [==============================] - 0s 11ms/step - loss: 16.6522 - mean_absolute_error: 3.2850 - val_loss: 225.0609 - val_mean_absolute_error: 14.4276
# Epoch 36/100
# 7/7 [==============================] - 0s 12ms/step - loss: 15.9054 - mean_absolute_error: 3.2245 - val_loss: 221.9974 - val_mean_absolute_error: 14.3220
# Epoch 37/100
# 7/7 [==============================] - 0s 12ms/step - loss: 15.1953 - mean_absolute_error: 3.1562 - val_loss: 221.7115 - val_mean_absolute_error: 14.3130
# Epoch 38/100
# 7/7 [==============================] - 0s 12ms/step - loss: 15.5718 - mean_absolute_error: 3.2247 - val_loss: 213.0471 - val_mean_absolute_error: 13.9970
# Epoch 39/100
# 7/7 [==============================] - 0s 13ms/step - loss: 15.2248 - mean_absolute_error: 3.1112 - val_loss: 214.2057 - val_mean_absolute_error: 14.0413
# Epoch 40/100
# 7/7 [==============================] - 0s 14ms/step - loss: 14.3141 - mean_absolute_error: 3.0287 - val_loss: 245.3644 - val_mean_absolute_error: 15.1086
# Epoch 41/100
# 7/7 [==============================] - 0s 15ms/step - loss: 14.4615 - mean_absolute_error: 3.0687 - val_loss: 206.3236 - val_mean_absolute_error: 13.7469
# Epoch 42/100
# 7/7 [==============================] - 0s 19ms/step - loss: 13.9960 - mean_absolute_error: 3.0745 - val_loss: 199.1419 - val_mean_absolute_error: 13.4763
# Epoch 43/100
# 7/7 [==============================] - 0s 12ms/step - loss: 15.8539 - mean_absolute_error: 3.1870 - val_loss: 195.4427 - val_mean_absolute_error: 13.3421
# Epoch 44/100
# 7/7 [==============================] - 0s 15ms/step - loss: 15.5217 - mean_absolute_error: 3.2232 - val_loss: 215.4120 - val_mean_absolute_error: 14.1042
# Epoch 45/100
# 7/7 [==============================] - 0s 13ms/step - loss: 15.5637 - mean_absolute_error: 3.1758 - val_loss: 211.2120 - val_mean_absolute_error: 13.9678
# Epoch 46/100
# 7/7 [==============================] - 0s 12ms/step - loss: 15.5661 - mean_absolute_error: 3.1504 - val_loss: 191.7371 - val_mean_absolute_error: 13.2767
# Epoch 47/100
# 7/7 [==============================] - 0s 15ms/step - loss: 20.6729 - mean_absolute_error: 3.6723 - val_loss: 179.0986 - val_mean_absolute_error: 12.7336
# Epoch 48/100
# 7/7 [==============================] - 0s 18ms/step - loss: 15.6588 - mean_absolute_error: 3.1463 - val_loss: 174.4460 - val_mean_absolute_error: 12.5228
# Epoch 49/100
# 7/7 [==============================] - 0s 11ms/step - loss: 16.3365 - mean_absolute_error: 3.3125 - val_loss: 172.3650 - val_mean_absolute_error: 12.4366
# Epoch 50/100
# 7/7 [==============================] - 0s 12ms/step - loss: 15.4526 - mean_absolute_error: 3.1515 - val_loss: 171.5831 - val_mean_absolute_error: 12.4014
# Epoch 51/100
# 7/7 [==============================] - 0s 14ms/step - loss: 15.9315 - mean_absolute_error: 3.2190 - val_loss: 174.1106 - val_mean_absolute_error: 12.5013
# Epoch 52/100
# 7/7 [==============================] - 0s 21ms/step - loss: 17.8479 - mean_absolute_error: 3.4363 - val_loss: 182.7178 - val_mean_absolute_error: 12.8770
# Epoch 53/100
# 7/7 [==============================] - 0s 22ms/step - loss: 14.2180 - mean_absolute_error: 2.9484 - val_loss: 188.7715 - val_mean_absolute_error: 13.1450
# Epoch 54/100
# 7/7 [==============================] - 0s 19ms/step - loss: 14.2844 - mean_absolute_error: 3.0380 - val_loss: 186.6947 - val_mean_absolute_error: 13.0189
# Epoch 55/100
# 7/7 [==============================] - 0s 18ms/step - loss: 14.1622 - mean_absolute_error: 2.9823 - val_loss: 174.3451 - val_mean_absolute_error: 12.5196
# Epoch 56/100
# 7/7 [==============================] - 0s 26ms/step - loss: 12.5592 - mean_absolute_error: 2.8633 - val_loss: 176.4193 - val_mean_absolute_error: 12.6096
# Epoch 57/100
# 7/7 [==============================] - 0s 20ms/step - loss: 12.5251 - mean_absolute_error: 2.9025 - val_loss: 170.6516 - val_mean_absolute_error: 12.3745
# Epoch 58/100
# 7/7 [==============================] - 0s 17ms/step - loss: 12.7996 - mean_absolute_error: 2.8193 - val_loss: 168.8753 - val_mean_absolute_error: 12.3216
# Epoch 59/100
# 7/7 [==============================] - 0s 21ms/step - loss: 12.2427 - mean_absolute_error: 2.8233 - val_loss: 163.5152 - val_mean_absolute_error: 12.0885
# Epoch 60/100
# 7/7 [==============================] - 0s 19ms/step - loss: 11.9000 - mean_absolute_error: 2.7942 - val_loss: 162.2268 - val_mean_absolute_error: 12.0287
# Epoch 61/100
# 7/7 [==============================] - 0s 18ms/step - loss: 13.6443 - mean_absolute_error: 2.9088 - val_loss: 158.4275 - val_mean_absolute_error: 11.8788
# Epoch 62/100
# 7/7 [==============================] - 0s 25ms/step - loss: 13.2223 - mean_absolute_error: 2.9182 - val_loss: 159.3731 - val_mean_absolute_error: 11.9417
# Epoch 63/100
# 7/7 [==============================] - 0s 20ms/step - loss: 12.6348 - mean_absolute_error: 2.8599 - val_loss: 164.8237 - val_mean_absolute_error: 12.1774
# Epoch 64/100
# 7/7 [==============================] - 0s 19ms/step - loss: 15.9215 - mean_absolute_error: 3.2668 - val_loss: 158.8600 - val_mean_absolute_error: 11.8947
# Epoch 65/100
# 7/7 [==============================] - 0s 22ms/step - loss: 15.2301 - mean_absolute_error: 3.1389 - val_loss: 151.0905 - val_mean_absolute_error: 11.5537
# Epoch 66/100
# 7/7 [==============================] - 0s 20ms/step - loss: 13.4027 - mean_absolute_error: 2.9235 - val_loss: 153.9772 - val_mean_absolute_error: 11.6758
# Epoch 67/100
# 7/7 [==============================] - 0s 21ms/step - loss: 13.5158 - mean_absolute_error: 2.9116 - val_loss: 157.1691 - val_mean_absolute_error: 11.8232
# Epoch 68/100
# 7/7 [==============================] - 0s 19ms/step - loss: 13.0339 - mean_absolute_error: 2.9122 - val_loss: 145.2263 - val_mean_absolute_error: 11.2847
# Epoch 69/100
# 7/7 [==============================] - 0s 17ms/step - loss: 14.5596 - mean_absolute_error: 3.1435 - val_loss: 151.1321 - val_mean_absolute_error: 11.5634
# Epoch 70/100
# 7/7 [==============================] - 0s 19ms/step - loss: 11.5901 - mean_absolute_error: 2.7223 - val_loss: 156.6248 - val_mean_absolute_error: 11.8155
# Epoch 71/100
# 7/7 [==============================] - 0s 20ms/step - loss: 12.7779 - mean_absolute_error: 2.8093 - val_loss: 156.6625 - val_mean_absolute_error: 11.8613
# Epoch 72/100
# 7/7 [==============================] - 0s 19ms/step - loss: 17.5888 - mean_absolute_error: 3.3340 - val_loss: 141.2138 - val_mean_absolute_error: 11.1153
# Epoch 73/100
# 7/7 [==============================] - 0s 20ms/step - loss: 14.3657 - mean_absolute_error: 3.1021 - val_loss: 146.7681 - val_mean_absolute_error: 11.3677
# Epoch 74/100
# 7/7 [==============================] - 0s 17ms/step - loss: 12.4843 - mean_absolute_error: 2.7707 - val_loss: 160.7905 - val_mean_absolute_error: 11.9874
# Epoch 75/100
# 7/7 [==============================] - 0s 18ms/step - loss: 12.5674 - mean_absolute_error: 2.8124 - val_loss: 146.9807 - val_mean_absolute_error: 11.3989
# Epoch 76/100
# 7/7 [==============================] - 0s 24ms/step - loss: 11.5238 - mean_absolute_error: 2.7193 - val_loss: 139.5306 - val_mean_absolute_error: 11.0427
# Epoch 77/100
# 7/7 [==============================] - 0s 19ms/step - loss: 12.6438 - mean_absolute_error: 2.8491 - val_loss: 143.1137 - val_mean_absolute_error: 11.2116
# Epoch 78/100
# 7/7 [==============================] - 0s 19ms/step - loss: 11.9546 - mean_absolute_error: 2.7674 - val_loss: 142.8586 - val_mean_absolute_error: 11.1989
# Epoch 79/100
# 7/7 [==============================] - 0s 19ms/step - loss: 11.5883 - mean_absolute_error: 2.7277 - val_loss: 146.6672 - val_mean_absolute_error: 11.3937
# Epoch 80/100
# 7/7 [==============================] - 0s 19ms/step - loss: 11.7992 - mean_absolute_error: 2.7262 - val_loss: 145.2853 - val_mean_absolute_error: 11.3272
# Epoch 81/100
# 7/7 [==============================] - 0s 19ms/step - loss: 12.3040 - mean_absolute_error: 2.8247 - val_loss: 140.7181 - val_mean_absolute_error: 11.1128
# Epoch 82/100
# 7/7 [==============================] - 0s 20ms/step - loss: 12.4289 - mean_absolute_error: 2.8759 - val_loss: 138.8620 - val_mean_absolute_error: 11.0197
# Epoch 83/100
# 7/7 [==============================] - 0s 22ms/step - loss: 11.3562 - mean_absolute_error: 2.6930 - val_loss: 141.3053 - val_mean_absolute_error: 11.1337
# Epoch 84/100
# 7/7 [==============================] - 0s 20ms/step - loss: 11.2031 - mean_absolute_error: 2.6846 - val_loss: 137.3221 - val_mean_absolute_error: 10.9610
# Epoch 85/100
# 7/7 [==============================] - 0s 19ms/step - loss: 11.3389 - mean_absolute_error: 2.6810 - val_loss: 138.2427 - val_mean_absolute_error: 11.0047
# Epoch 86/100
# 7/7 [==============================] - 0s 18ms/step - loss: 11.3894 - mean_absolute_error: 2.6746 - val_loss: 140.4772 - val_mean_absolute_error: 11.1089
# Epoch 87/100
# 7/7 [==============================] - 0s 20ms/step - loss: 11.4449 - mean_absolute_error: 2.6790 - val_loss: 138.9819 - val_mean_absolute_error: 11.0413
# Epoch 88/100
# 7/7 [==============================] - 0s 19ms/step - loss: 11.4363 - mean_absolute_error: 2.7003 - val_loss: 127.4526 - val_mean_absolute_error: 10.4656
# Epoch 89/100
# 7/7 [==============================] - 0s 13ms/step - loss: 14.1883 - mean_absolute_error: 3.0815 - val_loss: 146.7932 - val_mean_absolute_error: 11.4267
# Epoch 90/100
# 7/7 [==============================] - 0s 15ms/step - loss: 12.1755 - mean_absolute_error: 2.7586 - val_loss: 141.6113 - val_mean_absolute_error: 11.2117
# Epoch 91/100
# 7/7 [==============================] - 0s 11ms/step - loss: 11.7420 - mean_absolute_error: 2.6521 - val_loss: 144.0975 - val_mean_absolute_error: 11.3076
# Epoch 92/100
# 7/7 [==============================] - 0s 13ms/step - loss: 11.7379 - mean_absolute_error: 2.7666 - val_loss: 131.9155 - val_mean_absolute_error: 10.7254
# Epoch 93/100
# 7/7 [==============================] - 0s 11ms/step - loss: 11.5608 - mean_absolute_error: 2.6870 - val_loss: 122.5055 - val_mean_absolute_error: 10.2583
# Epoch 94/100
# 7/7 [==============================] - 0s 12ms/step - loss: 11.1246 - mean_absolute_error: 2.6123 - val_loss: 130.2154 - val_mean_absolute_error: 10.6746
# Epoch 95/100
# 7/7 [==============================] - 0s 14ms/step - loss: 11.6627 - mean_absolute_error: 2.6635 - val_loss: 125.9453 - val_mean_absolute_error: 10.4606
# Epoch 96/100
# 7/7 [==============================] - 0s 14ms/step - loss: 10.0897 - mean_absolute_error: 2.5187 - val_loss: 123.1381 - val_mean_absolute_error: 10.3086
# Epoch 97/100
# 7/7 [==============================] - 0s 12ms/step - loss: 9.9974 - mean_absolute_error: 2.5218 - val_loss: 121.6499 - val_mean_absolute_error: 10.2496
# Epoch 98/100
# 7/7 [==============================] - 0s 11ms/step - loss: 10.2295 - mean_absolute_error: 2.5327 - val_loss: 115.7316 - val_mean_absolute_error: 9.9459
# Epoch 99/100
# 7/7 [==============================] - 0s 11ms/step - loss: 11.1041 - mean_absolute_error: 2.6352 - val_loss: 118.8648 - val_mean_absolute_error: 10.1136
# Epoch 100/100
# 7/7 [==============================] - 0s 12ms/step - loss: 10.4492 - mean_absolute_error: 2.5084 - val_loss: 112.0761 - val_mean_absolute_error: 9.7788

# %%
train_predictions = model.predict(X_train).flatten()
test_predictions = model.predict(X_test).flatten()
val_predictions = model.predict(X_val).flatten()
# Out:
# 7/7 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 45ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %% [markdown]
# The model does better when trained on more relevant data.

# %%
model.save('')
